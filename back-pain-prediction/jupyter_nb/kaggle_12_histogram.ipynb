# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
df = pd.read_csv('../data/original.csv')
df.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# count     310.000000                310.000000    310.000000   310.000000
# mean      117.920655                 26.296694      0.472979    21.321526
# std        13.317377                 37.559027      0.285787     8.639423
# min        70.082575                -11.058179      0.003220     7.027000
# 25%       110.709196                  1.603727      0.224367    13.054400
# 50%       118.268178                 11.767934      0.475989    21.907150
# 75%       125.467674                 41.287352      0.704846    28.954075
# max       163.071041                418.543082      0.998827    36.743900
#
#        thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope
# count      310.000000     310.000000    310.000000       310.000000
# mean        13.064511      11.933317    -14.053139        25.645981
# std          3.399713       2.893265     12.225582        10.450558
# min          7.037800       7.030600    -35.287375         7.007900
# 25%         10.417800       9.541140    -24.289522        17.189075
# 50%         12.938450      11.953835    -14.622856        24.931950
# 75%         15.889525      14.371810     -3.497094        33.979600
# max         19.324000      16.821080      6.972071        44.341200

# %%
##################### PELVIC INCIDENCE ##########################
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
pi_normals = df.pelvic_incidence[df.Class_att == 'Normal']
pi_abnormals = df.pelvic_incidence[df.Class_att == 'Abnormal']

x_min = min(df.pelvic_incidence)
x_max = max(df.pelvic_incidence)
x_min = math.floor(x_min/10)*10
x_max = math.ceil(x_max/10)*10
ax1.set_xlim(x_min, x_max)

ax1.set_xlim(x_min, x_max)
plt.xlabel('pelvic incidence')
n, bins, patches = ax1.hist(pi_normals, bins=30, color ='g', alpha=0.2,density=True)
#print('normals - n:{}, bins:{}, patches:{}'.format(n, bins, patches))
n, bins, patches = ax1.hist(pi_abnormals, bins=30, color = 'r', alpha=0.2, density=True)
#print('abnormals - n:{}, bins:{}, patches:{}'.format(n, bins, patches))
#for val in df.pelvic_incidence:
#    if val > 90:
#        print(val)

# %% [markdown]
# The normal range for pelvic tilt is 13 +/- 7 deg

# %%
##################### PELVIC TILT ##########################
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
x_min = min(df.pelvic_tilt)
x_max = max(df.pelvic_tilt)

x_min = math.floor(x_min/10)*10
x_max = math.ceil(x_max/10)*10
ax1.set_xlim(x_min, x_max)
plt.xlabel('degrees pelvic tilt')
n, bins, patches = ax1.hist(df.pelvic_tilt[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
n, bins, patches = ax1.hist(df.pelvic_tilt[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### CERVICAL TILT ##########################
x_min = min(df.cervical_tilt)
x_max = max(df.cervical_tilt)
x_min = math.floor(x_min/10)*10
x_max = math.ceil(x_max/10)*10

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

plt.xlabel('degrees cervical tilt')
ax1.hist(df.cervical_tilt[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.cervical_tilt[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### LUMBAR LORDOSIS ANGLE ##########################
x_min = min(df.lumbar_lordosis_angle)
x_max = max(df.lumbar_lordosis_angle)
x_min = math.floor(x_min/10)*10
x_max = math.floor(x_max/10)*10
ax1.set_xlim(x_min, x_max)
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
plt.xlabel('lumbar lordosis angle')
arr1, bin1, patch1 = ax1.hist(df.lumbar_lordosis_angle[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
arr2, bin2, patch2 = ax1.hist(df.lumbar_lordosis_angle[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
norm_data = df[df['Class_att'] == 'Normal']

#for val in norm_data.lumbar_lordosis_angle:
#    if val < 76: #looking at graph for last val in data that looks as if not an outlier
#        print(val)
plt.show()

# %%
##################### SACRAL SLOPE ##########################
x_min = min(df.sacral_slope)
x_min = math.floor(x_min)
x_max = max(df.sacral_slope)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlim(x_min, x_max)
plt.xlabel('sacral slope')
ax1.hist(df.sacral_slope[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density = True)
ax1.hist(df.sacral_slope[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density = True)
plt.show()

# %%
##################### PELVIC RADIUS ##########################
x_min = min(df.pelvic_radius)
x_min = math.floor(x_min)
x_max = max(df.pelvic_radius)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlim(x_min, x_max)

plt.xlabel('pelvic radius')
ax1.hist(df.pelvic_radius[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.pelvic_radius[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### PELVIC RADIUS ##########################
#x_lim = [0, 175]
#y_lim = [0, 70]
fig, ax = plt.subplots()
plt.xlabel('pelvic radius')
pr_normals = df.pelvic_radius[df.Class_att == 'Normal'].values
print('normal values are: {}'.format(pr_normals))
pr_abnormals = df.pelvic_radius[df.Class_att == 'Abnormal'].values
print('abnormal values are: {}'.format(pr_abnormals))

x_min = min(np.min(pr_normals), np.min(pr_abnormals))

x_max = min(np.max(pr_normals), np.max(pr_abnormals))
print('max normals is: {}\nmax abnormals is: {}'.format(np.max(pr_normals), np.max(pr_abnormals)))

x_min = math.floor(x_min/10)*10

x_max = math.ceil(x_max/10)*10

x_lim = [x_min, x_max]

ax.hist(pr_normals, color = 'g', alpha=0.5, density=True)
ax.hist(pr_abnormals, color = 'r', alpha=0.5, density=True)
ax.set_xlim(x_lim)
#ax.set_ylim(y_lim)
plt.show()
# Out:
# normal values are: [127.6328747 125.8466462 129.220682  128.9803079 130.1783144 142.4101072
#  118.151531  132.114805  129.385308  106.1777511 113.7784936 126.9703283
#  116.2285032 103.5825398 100.5011917 125.1742214 142.3601245 118.6862678
#  123.8034132 137.4396942 124.1280012 118.1930354 128.5177217 139.1184721
#  135.740926  113.0659387 121.779803  133.2818339 126.6116215 139.1896903
#  116.5551679 126.7185156 131.5844199 123.9877408 114.5066078 125.3911378
#  119.3776026 121.4355585 120.5769719 122.343516  135.9369096 139.2471502
#  121.6068586 119.5503909 111.2340468 123.6322597 123.0379985 131.8024914
#  128.0099272 117.0897469 122.2090834 105.6453997 128.9056892 128.3253556
#  111.7911722 135.6233101 121.2476572 123.0912395 113.8061775 125.0143609
#  126.4722584 120.631941  117.8187599 126.9239062 123.4674001 137.5917777
#  131.3061224 129.3935728 119.3356546 139.1504066 119.1346221 115.3882683
#  113.9137026 126.3981876 121.0356423 119.6856451 120.9201997 120.3886112
#  105.417304  131.7176127 126.0768612 115.8037111 127.1398495 137.1082886
#  128.0636203 130.3500956 131.922009  116.7970069 128.9029049 110.7089577
#  116.5879699 111.4810746 118.3433212 128.3001991 147.8946372 117.4490622
#  114.365845  125.6707246 118.5458418 123.9452436]
# abnormal values are: [ 98.67291675 114.4054254  105.9851355  101.8684951  108.1687249
#  130.3278713  120.5675233  117.2700675  125.0028927   84.24141517
#  108.6482654  120.0553988  119.321358   110.9666978  116.8065868
#  124.1158358  112.3094915  129.0114183  123.1592507  116.5857056
#  134.4610156  125.2127163  106.4243295  117.9808303  115.5771163
#  121.447011   125.2032956  109.271634   111.0729197  113.4770183
#  112.192804    98.77454633 117.9803245  124.914118   119.3303537
#  113.8331446  132.264735   137.5406125  123.3118449  116.5597709
#  106.9388517  115.4814047  121.6709148  121.2196839  114.0231172
#  117.4222591  117.3846251  113.2666746  121.0462458  118.3633889
#  115.8770174  107.9493045  128.2925148  112.6841408  116.3778894
#   98.24978071 112.7761866  116.2509174  124.8461088  124.0564518
#  143.5606905  129.9554764  134.7117723  114.818751   123.9320096
#  115.012334   118.5303266   95.9036288  114.2130126  102.0428116
#  119.1937238  135.0753635  125.6595336  122.648753   137.7366546
#  148.5255624  139.414504    98.50115697 111.12397    117.5120039
#  112.1516     120.2059626  121.7647796  151.8398566  124.267007
#  163.0710405  119.3191109  130.0756599  127.2945222  119.8649383
#  114.7698556  116.1779325  124.4197875  113.5876551  114.8901128
#  140.9817119  120.6730408  109.3565941  123.0557067  115.514798
#  108.0102185  114.787107   102.3375244  110.8647831  118.4507311
#  116.5811088   94.73852542 138.5541111  110.6440206  123.4311742
#  114.1292425  126.9129899  111.5857819   96.49136982 141.0881494
#  107.690466   114.1900488  122.0929536  136.4403015  113.0533309
#  117.6432188  124.6460723  110.7099121  109.1627768  107.1822176
#   95.44375749 103.0083545  116.4389807  100.8921596  110.6903772
#   99.71245318 118.9306656  116.8030913  119.4250857  136.9725168
#  110.6111484  116.6015376  110.4665164  107.1723576  109.062312
#  105.0673556  134.6342912  110.6607005  117.2255542  105.1316639
#  105.1440758  114.8660487  109.9153669  104.3949585   98.62251165
#   94.01878339 125.3509625  111.9160075  116.7353868  103.3488802
#   82.45603817 118.5886691  108.6295666  103.0486975   95.25245421
#  115.72353     97.8010854   81.0245406  104.6986033  124.3978211
#  125.4801739  109.978045    70.08257486  89.3075466   98.27410705
#  111.679961   104.7312342   93.69220863  78.99945411 103.4045971
#   98.77711506 100.7154129   89.47183446 120.1034928  125.0185168
#  157.848799    90.298468   106.8295898  125.1642324  125.430176
#  117.3078968   90.07187999 109.0330745  120.8407069  117.0422439
#   88.43424213  97.4041888  146.4660009  119.2370072  116.9634162
#  110.703107    89.82274067 135.6294176  115.2087008  118.8833881
#  130.9992576  145.6010328  132.2672855   98.72792982 101.7233343
#  125.5936237   96.68390337 128.4057314  120.9448288   94.88233607]
# max normals is: 147.8946372
# max abnormals is: 163.0710405

# %%
##################### DEGREE SPONDYLOLITHESIS ##########################
#x_lim = [(-1, 400]
#y_lim = [0, 120]
x_min = min(df.degree_spondylolisthesis)
x_min = math.floor(x_min)

x_max = max(df.degree_spondylolisthesis)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

plt.xlabel('degree spondylolithesis')
n, bins, patches = ax1.hist(df.degree_spondylolisthesis[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
n, bins, patches = ax1.hist(df.degree_spondylolisthesis[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

abnorm_data = df[df['Class_att'] == 'Abnormal']
norm_data = df[df['Class_att'] == 'Normal']

#for val in abnorm_data.degree_spondylolisthesis:
#    if val > 90: 
#        print(val)
plt.show()

# %%
##################### PELVIC SLOPE ##########################
#x_lim = [0, 1]
#y_lim = [0, 30]
x_min = min(df.pelvic_slope)
x_min = math.floor(x_min)
x_max = max(df.pelvic_slope)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlim(x_min, x_max)

plt.xlabel('pelvic slope gradient')
ax1.hist(df.pelvic_slope[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.pelvic_slope[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### DIRECT TILT ##########################
#x_lim = [0, 40]
#y_lim = [0, 30]
x_min = min(df.direct_tilt)
x_min = math.floor(x_min)

x_max = max(df.direct_tilt)
x_max = math.floor(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ax1.set_xlim(x_min, x_max)

plt.xlabel('direct tilt')
ax1.hist(df.direct_tilt[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.direct_tilt[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### THORACIC SLOPE ##########################
#x_lim = [0, 25]
#y_lim = [0, 25]

x_min = min(df.thoracic_slope)
x_min = math.floor(x_min)

x_max = max(df.thoracic_slope)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlim(x_min, x_max)

plt.xlabel('thoracic slope angle')
ax1.hist(df.thoracic_slope[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.thoracic_slope[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### SACRUM ANGLE ##########################
#x_lim = [0, 25]
#y_lim = [0, 25]
x_min = min(df.sacrum_angle)
x_min = math.floor(x_min)

x_max = max(df.sacrum_angle)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlim(x_min, x_max)

plt.xlabel('sacrum angle')
ax1.hist(df.sacrum_angle[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.sacrum_angle[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()

# %%
##################### SCOLIOSIS SLOPE ##########################
#x_lim = [0, 50]
#y_lim = [0, 30]

x_min = min(df.scoliosis_slope)
x_min = math.floor(x_min)

x_max = max(df.scoliosis_slope)
x_max = math.ceil(x_max)

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ax1.set_xlim(x_min, x_max)

plt.xlabel('scoliosis slope angle')
ax1.hist(df.scoliosis_slope[df.Class_att == 'Normal'], color = 'g', alpha=0.2, density=True)
ax1.hist(df.scoliosis_slope[df.Class_att == 'Abnormal'], color = 'r', alpha=0.2, density=True)
plt.show()
