# %%
from numpy.random import seed
from numpy.random import randn
from statsmodels.graphics.gofplots import qqplot
from matplotlib import pyplot

import pandas as pd

# %%
data = pd.read_csv('../data/original.csv')

# q-q plot
qqplot(data.pelvic_incidence, line='s')

# %%
qqplot(data.lumbar_lordosis_angle, line='s')

# %%
qqplot(data.pelvic_tilt, line='s')

# %%
qqplot(data.pelvic_radius, line='s')

# %%
qqplot(data.sacral_slope, line='s')

# %%
qqplot(data.degree_spondylolisthesis, line='s')

# %%
qqplot(data.cervical_tilt, line='s')

# %%
qqplot(data.thoracic_slope, line='s')

# %%
qqplot(data.pelvic_slope, line='s')

# %%
qqplot(data.sacrum_angle, line='s')

# %%
qqplot(data.direct_tilt, line='s')

# %%
qqplot(data.scoliosis_slope, line='s')

# %%
pyplot.show()
